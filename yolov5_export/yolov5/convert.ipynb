# %%
import os 
import torch
from torchinfo import summary

# %%
ROOT = '/home/trojan/Desktop/temp2/'
model_path = os.path.join(ROOT, 'best/best.pt')

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path)  # default
# Out:
# Using cache found in /home/trojan/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2021-10-13 torch 1.9.1+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5943.3125MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# Adding AutoShape...

# %%
summary(model)
# Out:
# ...
# Layer (type:depth-idx)                             Param #
# ...
# AutoShape                                          --
# ├─Model: 1-1                                       --
# │    └─Sequential: 2-1                             --
# │    │    └─Focus: 3-1                             (3,488)
# │    │    └─Conv: 3-2                              (18,496)
# │    │    └─BottleneckCSP: 3-3                     (19,744)
# │    │    └─Conv: 3-4                              (73,856)
# │    │    └─BottleneckCSP: 3-5                     (160,576)
# │    │    └─Conv: 3-6                              (295,168)
# │    │    └─BottleneckCSP: 3-7                     (640,640)
# │    │    └─Conv: 3-8                              (1,180,160)
# │    │    └─SPP: 3-9                               (656,128)
# │    │    └─BottleneckCSP: 3-10                    (1,247,488)
# │    │    └─Conv: 3-11                             (131,328)
# │    │    └─Upsample: 3-12                         --
# ...

# %%
# !python export.py --weights $model_path --img 640 --batch 1 --opset 11
# Out:
# export: data=data/coco128.yaml, weights=/home/trojan/Desktop/temp2/best/best.pt, imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=11, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.0-3-g20a809d torch 1.9.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
#
# PyTorch: starting from /home/trojan/Desktop/temp2/best/best.pt (14.8 MB)
#
# TorchScript: starting export with torch 1.9.1+cu102...
# /home/trojan/Desktop/temp2/yolov5/models/yolo.py:60: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.grid[i].shape[2:4] != x[i].shape[2:4] or self.onnx_dynamic:
# ...

# %%
# !python export.py --train --weights $model_path --img 640 --batch 1 --include 'coreml'  # export at 640x640 with batch size 1
# Out:
# export: data=data/coco128.yaml, weights=/home/trojan/Desktop/temp2/best/best.pt, imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, train=True, optimize=False, int8=False, dynamic=False, simplify=False, opset=13, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['coreml']
# YOLOv5 🚀 v6.0-3-g20a809d torch 1.9.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
#
# PyTorch: starting from /home/trojan/Desktop/temp2/best/best.pt (14.8 MB)
#
# CoreML: starting export with coremltools 4.1...
# Tuple detected at graph output. This will be flattened in the converted model.
# Converting graph.
# Adding op '1' of type const
# Adding op '2' of type const
# Adding op '3' of type const
# Adding op '4' of type const
# Adding op '5' of type const
# Adding op '6' of type const
# Adding op '7' of type const
# Adding op '8' of type const
# Adding op '9' of type const
# Adding op '10' of type const
# ...

# %%
# testing pretrained
# !python export.py --weights yolov5s.pt --img 640 --batch 1
# Out:
# export: data=data/coco128.yaml, weights=yolov5s.pt, imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=13, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.0-3-g20a809d torch 1.9.1+cu102 CPU
#
# ...
# 100%|██████████████████████████████████████| 14.0M/14.0M [00:00<00:00, 33.6MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
#
# PyTorch: starting from yolov5s.pt (14.7 MB)
#
# TorchScript: starting export with torch 1.9.1+cu102...
# /home/trojan/Desktop/temp2/yolov5/models/yolo.py:60: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# ...

# %%
# !python export.py --weights yolov5s.pt --img 640 --batch 1 --include 'coreml'
# Out:
# export: data=data/coco128.yaml, weights=yolov5s.pt, imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=13, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['coreml']
# YOLOv5 🚀 v6.0-3-g20a809d torch 1.9.1+cu102 CPU
#
# ...
# 100%|██████████████████████████████████████| 14.0M/14.0M [00:00<00:00, 63.0MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
#
# PyTorch: starting from yolov5s.pt (14.7 MB)
#
# CoreML: starting export with coremltools 4.1...
# Tuple detected at graph output. This will be flattened in the converted model.
# Converting graph.
# Adding op '1' of type const
# Adding op '2' of type const
# Adding op '3' of type const
# Adding op '4' of type const
# Adding op '5' of type const
# Adding op '6' of type const
# Adding op '7' of type const
# Adding op '8' of type const
# Adding op '9' of type const
# ...
